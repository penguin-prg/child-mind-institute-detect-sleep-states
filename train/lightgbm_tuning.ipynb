# %%
import pandas as pd
import yaml
import sys
import os
from glob import glob
from pathlib import Path
import gc
import pickle
import joblib

import warnings
warnings.filterwarnings('ignore')

sys.path.append('/kaggle/src')
from utils.lgb import fit_lgb
from utils.metric import compute_comptetition_metric
from utils.set_seed import seed_base
from feature_engineering.fe_xgb import generate_features

MODEL_NAME = "lgb_model"
PACKAGE_DIR = Path("/kaggle/src")
CFG = yaml.safe_load(open(PACKAGE_DIR / "config.yaml", "r"))
print(CFG[MODEL_NAME]["execution"]["exp_id"])

CFG["output_dir"] = f"/kaggle/output/{CFG[MODEL_NAME]['execution']['exp_id']}"
# !rm -r {CFG["output_dir"]}
os.makedirs(CFG["output_dir"], exist_ok=True)

seed_base(CFG["env"]["seed"])
# Out:
# 2023-11-09 05:30:28.049068: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-09 05:30:28.117151: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-09 05:30:28.570288: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-11-09 05:30:28.570374: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib
# 2023-11-09 05:30:28.570379: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# exp_129
# rm: cannot remove '/kaggle/output/exp_129': No such file or directory

# %%
# 特徴生成
files = glob(f"{CFG['dataset']['step_csv_dir']}/*.parquet")
train, features = generate_features(files)

# cv splitとマージ
cv_split = pd.read_csv(CFG['dataset']['cv_split_path'])
train["fold"] = train["series_id"].map(cv_split.set_index("series_id")["fold"])
display(train.head(5))
train.shape
# Out:
# generate features: 100%|██████████| 277/277 [04:27<00:00,  1.04it/s]
#        anglez  anglez_diff_abs  anglez_diff_abs_clip5  anglez_mean      enmo  \
# 29 -89.259064         0.057546               0.057546   -10.070161  0.029858
# 30 -87.457848         0.147454               0.147454    -0.726222  0.029458
# 31 -86.225922         0.169739               0.169739    -5.723403  0.030287
# 32 -75.722588         5.349769               2.968245    -4.199389  0.083004
# 33  -0.061125         3.569804               1.781771     2.269062  0.021142
#
#     enmo_diff_abs  enmo_mean  minutes  same_count  total_seconds  ...  \
# 29       0.000262   0.104063    837.5         0.0        47637.5  ...
# 30       0.000533   0.095024    957.5         0.0        47757.5  ...
# 31       0.001758   0.092043   1077.5         0.0        47877.5  ...
# 32       0.049383   0.083214   1197.5         0.0        47997.5  ...
# 33       0.006329   0.088176   1317.5         0.0        48117.5  ...
#
#     enmo_rolling_median_100_shift_1000  \
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
#
#     anglez_diff_abs_clip5_rolling_median_100_shift_1000  \
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#     enmo_std_rolling_median_100_shift_1000  \
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
#
#     anglez_diff_abs_clip5_std_rolling_median_100_shift_1000  \
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#     enmo_rolling_square_mean_100_shift_1000  \
# 29                                      NaN
# 30                                      NaN
# 31                                      NaN
# 32                                      NaN
# 33                                      NaN
#
#     anglez_diff_abs_clip5_rolling_square_mean_100_shift_1000  \
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#     enmo_std_rolling_square_mean_100_shift_1000  \
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
#
#     anglez_diff_abs_clip5_std_rolling_square_mean_100_shift_1000  reduce_step  \
# 29                                                NaN                     707
# 30                                                NaN                     731
# 31                                                NaN                     755
# 32                                                NaN                     779
# 33                                                NaN                     803
#
#     fold
# 29     3
# 30     3
# 31     3
# 32     3
# 33     3
#
# [5 rows x 1307 columns]
# (493733, 1307)

# %%
from utils.postprocess import dynamic_range_nms
from multiprocessing import Pool
from tqdm import tqdm

def objective(trial):
    reg_alpha = trial.suggest_loguniform('reg_alpha', 1e-3, 1e3)
    reg_lambda = trial.suggest_loguniform('reg_lambda', 1e-3, 1e3)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.2, 0.8)
    num_leaves = trial.suggest_int('num_leaves', 10, 70)

    CFG[MODEL_NAME]["lightgbm"]["learning_rate"] = 0.1
    CFG[MODEL_NAME]["lightgbm"]["reg_alpha"] = reg_alpha
    CFG[MODEL_NAME]["lightgbm"]["reg_lambda"] = reg_lambda
    CFG[MODEL_NAME]["lightgbm"]["max_depth"] = max_depth
    CFG[MODEL_NAME]["lightgbm"]["colsample_bytree"] = colsample_bytree
    CFG[MODEL_NAME]["lightgbm"]["num_leaves"] = num_leaves

    # 学習
    dfs = []
    for event in ["wakeup", "onset"]:
        trn_oof, models = fit_lgb(
            X=train, 
            y=train[f"{event}_target"], 
            folds=train["fold"].astype(int), 
            features=features.all_features(),
            params=CFG[MODEL_NAME]["lightgbm"], 
            es_rounds=200,
            verbose=0,
            log=False,
            only_fold0=True,
        )
        train["score"] = trn_oof
        train["event"] = event
        dfs.append(train[["series_id", "step", "score", "event"]])
    gc.collect()
    oof = pd.concat(dfs, axis=0)
    oof["step"] = oof["step"].astype(int)
    oof = oof.sort_values(["series_id", "step"]).reset_index(drop=True)

    # post process
    oof = oof[oof["score"] > 0.005]
    oof["step"] = oof["step"].astype(int)
    groups = [group for _, group in oof.groupby("series_id")]
    with Pool(30) as p:  
        results = list(tqdm(p.imap(dynamic_range_nms, groups), total=len(groups)))
    sub = pd.concat(results)
    sub["score"] = sub["reduced_score"]
    
    labels = pd.read_csv(f"{CFG['dataset']['competition_dir']}/train_events.csv").dropna()
    labels = labels[labels["series_id"].isin(sub["series_id"].unique())]
    score, ap_table = compute_comptetition_metric(labels, sub)

    return score

# %%
import optuna

study = optuna.create_study(direction='maximize')
study.enqueue_trial({
    "reg_alpha": 0.02,
    "reg_lambda": 0.2,
    "max_depth": 7,
    "num_leaves": 40,
    "colsample_bytree": 0.7,
})
study.optimize(objective, n_trials=50)

print(f'best_params: {study.best_params}')
print(f'best_value: {study.best_value}')
display(study.trials_dataframe().sort_values("value", ascending=False).head(10))
study.trials_dataframe().to_csv(os.path.join(CFG["output_dir"], "xgb_optuna_result.csv"), index=False)
# Out:
# [I 2023-11-09 05:35:05,993] A new study created in memory with name: no-name-663fa742-ab4a-4d16-8641-21b0ed720a65
# 100%|██████████| 55/55 [00:01<00:00, 50.79it/s]
# [I 2023-11-09 05:37:23,135] Trial 0 finished with value: 0.7716001261243699 and parameters: {'reg_alpha': 0.02, 'reg_lambda': 0.2, 'max_depth': 7, 'colsample_bytree': 0.7, 'num_leaves': 40}. Best is trial 0 with value: 0.7716001261243699.
# 100%|██████████| 55/55 [00:01<00:00, 47.65it/s]
# [I 2023-11-09 05:39:25,743] Trial 1 finished with value: 0.7720642160298445 and parameters: {'reg_alpha': 12.866118450307523, 'reg_lambda': 9.711159190476145, 'max_depth': 10, 'colsample_bytree': 0.6462188274051617, 'num_leaves': 45}. Best is trial 1 with value: 0.7720642160298445.
# 100%|██████████| 55/55 [00:01<00:00, 44.39it/s]
# [I 2023-11-09 05:41:50,835] Trial 2 finished with value: 0.7738979065455843 and parameters: {'reg_alpha': 167.22110175249878, 'reg_lambda': 0.5309479510020025, 'max_depth': 8, 'colsample_bytree': 0.5649846715886738, 'num_leaves': 39}. Best is trial 2 with value: 0.7738979065455843.
# 100%|██████████| 55/55 [00:01<00:00, 51.49it/s]
# [I 2023-11-09 05:43:49,609] Trial 3 finished with value: 0.7759937906342504 and parameters: {'reg_alpha': 42.162800712654864, 'reg_lambda': 4.662809072890482, 'max_depth': 7, 'colsample_bytree': 0.39935719014695625, 'num_leaves': 44}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 50.10it/s]
# [I 2023-11-09 05:45:58,902] Trial 4 finished with value: 0.7743084013880992 and parameters: {'reg_alpha': 0.005689274865178575, 'reg_lambda': 354.6667559530893, 'max_depth': 9, 'colsample_bytree': 0.3701882975348659, 'num_leaves': 15}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 45.08it/s]
# [I 2023-11-09 05:49:54,748] Trial 5 finished with value: 0.7700057308399714 and parameters: {'reg_alpha': 83.28113473961992, 'reg_lambda': 45.92445427480482, 'max_depth': 3, 'colsample_bytree': 0.5196069878628267, 'num_leaves': 26}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 49.38it/s]
# [I 2023-11-09 05:51:46,471] Trial 6 finished with value: 0.7728237377731593 and parameters: {'reg_alpha': 32.260536260982, 'reg_lambda': 0.4191575367649387, 'max_depth': 9, 'colsample_bytree': 0.3620749398309258, 'num_leaves': 24}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 45.90it/s]
# [I 2023-11-09 05:54:03,717] Trial 7 finished with value: 0.768515968749088 and parameters: {'reg_alpha': 0.01854905186547689, 'reg_lambda': 19.908239142663092, 'max_depth': 8, 'colsample_bytree': 0.40768818476555607, 'num_leaves': 10}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 43.36it/s]
# [I 2023-11-09 05:56:07,119] Trial 8 finished with value: 0.7735519648673848 and parameters: {'reg_alpha': 0.002385750635531517, 'reg_lambda': 818.3064566746001, 'max_depth': 8, 'colsample_bytree': 0.270644622518957, 'num_leaves': 23}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 44.26it/s]
# [I 2023-11-09 05:58:56,034] Trial 9 finished with value: 0.7675291614342374 and parameters: {'reg_alpha': 0.169566427340226, 'reg_lambda': 50.67117207218349, 'max_depth': 3, 'colsample_bytree': 0.4458404003346811, 'num_leaves': 69}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 43.49it/s]
# [I 2023-11-09 06:00:40,527] Trial 10 finished with value: 0.7692507183354094 and parameters: {'reg_alpha': 732.8934082581195, 'reg_lambda': 0.007767308544728828, 'max_depth': 5, 'colsample_bytree': 0.21833406728450838, 'num_leaves': 63}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 46.84it/s]
# [I 2023-11-09 06:02:45,083] Trial 11 finished with value: 0.7707411939324933 and parameters: {'reg_alpha': 2.622290376062547, 'reg_lambda': 402.90788774251695, 'max_depth': 5, 'colsample_bytree': 0.3297102605361302, 'num_leaves': 53}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 43.56it/s]
# [I 2023-11-09 06:04:45,893] Trial 12 finished with value: 0.7702810383088912 and parameters: {'reg_alpha': 1.4427425260183235, 'reg_lambda': 5.473755035067198, 'max_depth': 6, 'colsample_bytree': 0.4386611957200784, 'num_leaves': 15}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 49.49it/s]
# [I 2023-11-09 06:06:41,228] Trial 13 finished with value: 0.7748899550456566 and parameters: {'reg_alpha': 0.31378001394794436, 'reg_lambda': 175.31808625993938, 'max_depth': 10, 'colsample_bytree': 0.32577992506025427, 'num_leaves': 32}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 47.73it/s]
# [I 2023-11-09 06:08:09,851] Trial 14 finished with value: 0.7692100349202349 and parameters: {'reg_alpha': 0.35426528257455037, 'reg_lambda': 2.7384766172034367, 'max_depth': 10, 'colsample_bytree': 0.3003947512520332, 'num_leaves': 34}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 44.09it/s]
# [I 2023-11-09 06:10:35,097] Trial 15 finished with value: 0.7677141956134119 and parameters: {'reg_alpha': 6.9523901730659246, 'reg_lambda': 121.30974408338452, 'max_depth': 6, 'colsample_bytree': 0.7985940961431183, 'num_leaves': 55}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 44.93it/s]
# [I 2023-11-09 06:12:42,489] Trial 16 finished with value: 0.7711776245281945 and parameters: {'reg_alpha': 0.3728570790044508, 'reg_lambda': 61.08906925028731, 'max_depth': 4, 'colsample_bytree': 0.2305300810236217, 'num_leaves': 31}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 48.67it/s]
# [I 2023-11-09 06:14:19,635] Trial 17 finished with value: 0.7707171427203565 and parameters: {'reg_alpha': 6.220489389145091, 'reg_lambda': 2.280829522139512, 'max_depth': 7, 'colsample_bytree': 0.3085157104741037, 'num_leaves': 48}. Best is trial 3 with value: 0.7759937906342504.
# 100%|██████████| 55/55 [00:01<00:00, 49.20it/s]
# [I 2023-11-09 06:16:06,224] Trial 18 finished with value: 0.7779477664093645 and parameters: {'reg_alpha': 1.0085303887352641, 'reg_lambda': 10.32610667162794, 'max_depth': 9, 'colsample_bytree': 0.4540970973784533, 'num_leaves': 33}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.77it/s]
# [I 2023-11-09 06:17:58,278] Trial 19 finished with value: 0.7732123308498559 and parameters: {'reg_alpha': 28.356645908590526, 'reg_lambda': 12.72568221108181, 'max_depth': 9, 'colsample_bytree': 0.4875214960166789, 'num_leaves': 45}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.17it/s]
# [I 2023-11-09 06:19:57,421] Trial 20 finished with value: 0.7742328140523798 and parameters: {'reg_alpha': 1.4602422058262952, 'reg_lambda': 1.3616234993488479, 'max_depth': 7, 'colsample_bytree': 0.39852418948772333, 'num_leaves': 55}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.88it/s]
# [I 2023-11-09 06:21:50,784] Trial 21 finished with value: 0.7691158387116889 and parameters: {'reg_alpha': 0.1418999442491213, 'reg_lambda': 141.42329237691294, 'max_depth': 10, 'colsample_bytree': 0.34866259555321694, 'num_leaves': 33}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 47.22it/s]
# [I 2023-11-09 06:23:40,053] Trial 22 finished with value: 0.7725344228858151 and parameters: {'reg_alpha': 3.904534764522114, 'reg_lambda': 15.880142339122772, 'max_depth': 9, 'colsample_bytree': 0.44189401538174605, 'num_leaves': 36}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 46.35it/s]
# [I 2023-11-09 06:25:16,710] Trial 23 finished with value: 0.7709631646641799 and parameters: {'reg_alpha': 0.6984199143587062, 'reg_lambda': 3.9081702545633523, 'max_depth': 10, 'colsample_bytree': 0.37332443359473366, 'num_leaves': 28}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.67it/s]
# [I 2023-11-09 06:27:11,404] Trial 24 finished with value: 0.7743433448469623 and parameters: {'reg_alpha': 0.11470664921814436, 'reg_lambda': 995.4543396488496, 'max_depth': 8, 'colsample_bytree': 0.2732380423939602, 'num_leaves': 43}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.74it/s]
# [I 2023-11-09 06:29:05,597] Trial 25 finished with value: 0.7724547223194311 and parameters: {'reg_alpha': 1.4512930619156288, 'reg_lambda': 24.614574297973363, 'max_depth': 9, 'colsample_bytree': 0.4858557539729512, 'num_leaves': 21}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.17it/s]
# [I 2023-11-09 06:30:47,007] Trial 26 finished with value: 0.7744733299213584 and parameters: {'reg_alpha': 12.539617903314445, 'reg_lambda': 139.65750036491335, 'max_depth': 10, 'colsample_bytree': 0.3349649788582335, 'num_leaves': 50}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.94it/s]
# [I 2023-11-09 06:32:38,518] Trial 27 finished with value: 0.7750309981764406 and parameters: {'reg_alpha': 0.063169610512401, 'reg_lambda': 6.549307823798659, 'max_depth': 8, 'colsample_bytree': 0.40108163285137327, 'num_leaves': 37}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 47.57it/s]
# [I 2023-11-09 06:34:33,936] Trial 28 finished with value: 0.7730548679203385 and parameters: {'reg_alpha': 0.07594120967643307, 'reg_lambda': 5.447936963128759, 'max_depth': 6, 'colsample_bytree': 0.4129968502803936, 'num_leaves': 38}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 47.42it/s]
# [I 2023-11-09 06:36:36,080] Trial 29 finished with value: 0.7706480431443853 and parameters: {'reg_alpha': 0.032024205980721164, 'reg_lambda': 0.1448188919232638, 'max_depth': 7, 'colsample_bytree': 0.5303013611683108, 'num_leaves': 60}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 44.11it/s]
# [I 2023-11-09 06:38:26,764] Trial 30 finished with value: 0.773725007769511 and parameters: {'reg_alpha': 0.03977307986077872, 'reg_lambda': 1.147908767945066, 'max_depth': 8, 'colsample_bytree': 0.4651856114234626, 'num_leaves': 41}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 44.02it/s]
# [I 2023-11-09 06:40:00,940] Trial 31 finished with value: 0.7723068119289882 and parameters: {'reg_alpha': 0.5535105364995042, 'reg_lambda': 8.594569225945477, 'max_depth': 9, 'colsample_bytree': 0.4113907085890951, 'num_leaves': 29}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.77it/s]
# [I 2023-11-09 06:42:01,187] Trial 32 finished with value: 0.7720725043279113 and parameters: {'reg_alpha': 0.26913215007472063, 'reg_lambda': 20.85331232319605, 'max_depth': 8, 'colsample_bytree': 0.3694297348717056, 'num_leaves': 37}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.50it/s]
# [I 2023-11-09 06:44:11,136] Trial 33 finished with value: 0.7738053887450066 and parameters: {'reg_alpha': 0.86826449205809, 'reg_lambda': 7.9866669981306995, 'max_depth': 7, 'colsample_bytree': 0.592236581826659, 'num_leaves': 41}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 43.02it/s]
# [I 2023-11-09 06:45:57,472] Trial 34 finished with value: 0.7748607239648644 and parameters: {'reg_alpha': 0.014317822064093821, 'reg_lambda': 2.537348902244131, 'max_depth': 10, 'colsample_bytree': 0.45985450998311006, 'num_leaves': 32}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 43.61it/s]
# [I 2023-11-09 06:47:47,957] Trial 35 finished with value: 0.7741913324966454 and parameters: {'reg_alpha': 0.2012269054079488, 'reg_lambda': 41.13956380761801, 'max_depth': 9, 'colsample_bytree': 0.5056347529390893, 'num_leaves': 45}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.96it/s]
# [I 2023-11-09 06:49:42,321] Trial 36 finished with value: 0.7725282895296413 and parameters: {'reg_alpha': 0.06788834521983801, 'reg_lambda': 0.5955954438032687, 'max_depth': 8, 'colsample_bytree': 0.3985083517894704, 'num_leaves': 19}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 44.04it/s]
# [I 2023-11-09 06:51:27,998] Trial 37 finished with value: 0.7730462166603871 and parameters: {'reg_alpha': 0.00763276885083771, 'reg_lambda': 7.930071165576101, 'max_depth': 9, 'colsample_bytree': 0.5392743265825445, 'num_leaves': 27}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 47.95it/s]
# [I 2023-11-09 06:53:39,445] Trial 38 finished with value: 0.7749120699544859 and parameters: {'reg_alpha': 2.510119124568396, 'reg_lambda': 285.4809743334411, 'max_depth': 7, 'colsample_bytree': 0.3574068663631704, 'num_leaves': 35}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.65it/s]
# [I 2023-11-09 06:55:44,474] Trial 39 finished with value: 0.772300257074588 and parameters: {'reg_alpha': 2.6824648786146463, 'reg_lambda': 24.394309786413075, 'max_depth': 6, 'colsample_bytree': 0.3798917828916348, 'num_leaves': 39}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.78it/s]
# [I 2023-11-09 06:57:50,568] Trial 40 finished with value: 0.7747590688586168 and parameters: {'reg_alpha': 72.785864972934, 'reg_lambda': 76.78195710051801, 'max_depth': 7, 'colsample_bytree': 0.4177027839084666, 'num_leaves': 48}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 43.61it/s]
# [I 2023-11-09 06:59:54,305] Trial 41 finished with value: 0.7728963396986128 and parameters: {'reg_alpha': 0.5359102484439134, 'reg_lambda': 278.8210799196524, 'max_depth': 8, 'colsample_bytree': 0.34327341824683333, 'num_leaves': 31}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 49.47it/s]
# [I 2023-11-09 07:01:43,063] Trial 42 finished with value: 0.774155771035508 and parameters: {'reg_alpha': 0.26752563400269697, 'reg_lambda': 250.34587888486536, 'max_depth': 8, 'colsample_bytree': 0.3786058278937169, 'num_leaves': 35}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 47.89it/s]
# [I 2023-11-09 07:03:51,666] Trial 43 finished with value: 0.7738801301606545 and parameters: {'reg_alpha': 261.96327940619085, 'reg_lambda': 38.21166905437337, 'max_depth': 7, 'colsample_bytree': 0.3136959661479798, 'num_leaves': 25}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.50it/s]
# [I 2023-11-09 07:05:56,350] Trial 44 finished with value: 0.7721733986656198 and parameters: {'reg_alpha': 26.21939127237489, 'reg_lambda': 436.998968786944, 'max_depth': 5, 'colsample_bytree': 0.35427556052678477, 'num_leaves': 42}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 50.13it/s]
# [I 2023-11-09 07:08:06,712] Trial 45 finished with value: 0.7730378617871736 and parameters: {'reg_alpha': 1.244935292008025, 'reg_lambda': 625.8844435799223, 'max_depth': 9, 'colsample_bytree': 0.4654145398177499, 'num_leaves': 37}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.87it/s]
# [I 2023-11-09 07:10:07,950] Trial 46 finished with value: 0.7772518110769525 and parameters: {'reg_alpha': 10.113794825562572, 'reg_lambda': 212.7700738663411, 'max_depth': 10, 'colsample_bytree': 0.42401866072359784, 'num_leaves': 29}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 50.15it/s]
# [I 2023-11-09 07:12:04,635] Trial 47 finished with value: 0.7743022387880515 and parameters: {'reg_alpha': 11.340200617492487, 'reg_lambda': 81.14773953508495, 'max_depth': 7, 'colsample_bytree': 0.4316483211653491, 'num_leaves': 23}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 48.67it/s]
# [I 2023-11-09 07:14:00,781] Trial 48 finished with value: 0.7737607711277756 and parameters: {'reg_alpha': 4.4377477070537505, 'reg_lambda': 277.5978122059065, 'max_depth': 8, 'colsample_bytree': 0.3929417841157459, 'num_leaves': 19}. Best is trial 18 with value: 0.7779477664093645.
# 100%|██████████| 55/55 [00:01<00:00, 43.37it/s]
# [I 2023-11-09 07:16:12,529] Trial 49 finished with value: 0.7716625390187848 and parameters: {'reg_alpha': 19.43670771124234, 'reg_lambda': 507.8755063849454, 'max_depth': 6, 'colsample_bytree': 0.45464814328795095, 'num_leaves': 30}. Best is trial 18 with value: 0.7779477664093645.
# best_params: {'reg_alpha': 1.0085303887352641, 'reg_lambda': 10.32610667162794, 'max_depth': 9, 'colsample_bytree': 0.4540970973784533, 'num_leaves': 33}
# best_value: 0.7779477664093645
#     number     value             datetime_start          datetime_complete  \
# 18      18  0.777948 2023-11-09 06:14:19.636183 2023-11-09 06:16:06.224571
# 46      46  0.777252 2023-11-09 07:08:06.712972 2023-11-09 07:10:07.949552
# 3        3  0.775994 2023-11-09 05:41:50.836664 2023-11-09 05:43:49.609420
# 27      27  0.775031 2023-11-09 06:30:47.008489 2023-11-09 06:32:38.518067
# 38      38  0.774912 2023-11-09 06:51:27.998788 2023-11-09 06:53:39.444832
# 13      13  0.774890 2023-11-09 06:04:45.894367 2023-11-09 06:06:41.228454
# 34      34  0.774861 2023-11-09 06:44:11.137343 2023-11-09 06:45:57.471653
# 40      40  0.774759 2023-11-09 06:55:44.475035 2023-11-09 06:57:50.567870
# 26      26  0.774473 2023-11-09 06:29:05.598146 2023-11-09 06:30:47.007095
# 24      24  0.774343 2023-11-09 06:25:16.711269 2023-11-09 06:27:11.403777
#
#                  duration  params_colsample_bytree  params_max_depth  \
# 18 0 days 00:01:46.588388                 0.454097                 9
# 46 0 days 00:02:01.236580                 0.424019                10
# 3  0 days 00:01:58.772756                 0.399357                 7
# 27 0 days 00:01:51.509578                 0.401082                 8
# 38 0 days 00:02:11.446044                 0.357407                 7
# 13 0 days 00:01:55.334087                 0.325780                10
# 34 0 days 00:01:46.334310                 0.459855                10
# 40 0 days 00:02:06.092835                 0.417703                 7
# 26 0 days 00:01:41.408949                 0.334965                10
# 24 0 days 00:01:54.692508                 0.273238                 8
#
#     params_num_leaves  params_reg_alpha  params_reg_lambda  \
# 18                 33          1.008530          10.326107
# 46                 29         10.113795         212.770074
# 3                  44         42.162801           4.662809
# 27                 37          0.063170           6.549308
# 38                 35          2.510119         285.480974
# 13                 32          0.313780         175.318086
# 34                 32          0.014318           2.537349
# 40                 48         72.785865          76.781957
# 26                 50         12.539618         139.657500
# 24                 43          0.114707         995.454340
#
#    system_attrs_fixed_params     state
# 18                       NaN  COMPLETE
# 46                       NaN  COMPLETE
# 3                        NaN  COMPLETE
# 27                       NaN  COMPLETE
# 38                       NaN  COMPLETE
# 13                       NaN  COMPLETE
# 34                       NaN  COMPLETE
# 40                       NaN  COMPLETE
# 26                       NaN  COMPLETE
# 24                       NaN  COMPLETE
